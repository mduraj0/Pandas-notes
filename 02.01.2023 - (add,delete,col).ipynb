# %%
import pandas as pd

# %%
fuel = pd.read_csv('../data/fuel.csv',
                   low_memory=False,
                   usecols=['Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)'])

# %%
fuel.head()
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class Fuel Type  Combined MPG (FT1)
# 0             Minicompact Cars   Regular                20.0
# 1             Minicompact Cars   Regular                20.0
# 2                  Two Seaters   Regular                21.0
# 3                  Two Seaters   Regular                21.0
# 4  Special Purpose Vehicle 2WD   Regular                17.0

# %%
fuel['Combined KPL'] = fuel['Combined MPG (FT1)'] * 1.609 / 3.78

# %%
fuel.head()
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class Fuel Type  Combined MPG (FT1)  Combined KPL
# 0             Minicompact Cars   Regular                20.0      8.513228
# 1             Minicompact Cars   Regular                20.0      8.513228
# 2                  Two Seaters   Regular                21.0      8.938889
# 3                  Two Seaters   Regular                21.0      8.938889
# 4  Special Purpose Vehicle 2WD   Regular                17.0      7.236243

# %%
fuel.insert(loc=5, column='liters per km', value=100 / fuel['Combined MPG (FT1)'])

# %%
fuel.head()
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class  liters per km Fuel Type  Combined MPG (FT1)  \
# 0             Minicompact Cars       5.000000   Regular                20.0
# 1             Minicompact Cars       5.000000   Regular                20.0
# 2                  Two Seaters       4.761905   Regular                21.0
# 3                  Two Seaters       4.761905   Regular                21.0
# 4  Special Purpose Vehicle 2WD       5.882353   Regular                17.0
#
#    Combined KPL
# 0      8.513228
# 1      8.513228
# 2      8.938889
# 3      8.938889
# 4      7.236243

# %%
del fuel['Combined MPG (FT1)']

# %%
fuel.head()
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class  liters per km Fuel Type  Combined KPL
# 0             Minicompact Cars       5.000000   Regular      8.513228
# 1             Minicompact Cars       5.000000   Regular      8.513228
# 2                  Two Seaters       4.761905   Regular      8.938889
# 3                  Two Seaters       4.761905   Regular      8.938889
# 4  Special Purpose Vehicle 2WD       5.882353   Regular      7.236243

# %%
fuel.drop(labels='Combined KPL', axis=1, inplace=True)

# %%
fuel.head()
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class  liters per km Fuel Type
# 0             Minicompact Cars       5.000000   Regular
# 1             Minicompact Cars       5.000000   Regular
# 2                  Two Seaters       4.761905   Regular
# 3                  Two Seaters       4.761905   Regular
# 4  Special Purpose Vehicle 2WD       5.882353   Regular
