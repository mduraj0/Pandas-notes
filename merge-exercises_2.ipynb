# %%
import pandas as pd
import numpy as np

# %%
suppliers = pd.read_csv('../data/northwind-mongo-master/suppliers.csv',
                       usecols=['SupplierID', 'CompanyName', 'City'])

# %%
products = pd.read_csv('../data/northwind-mongo-master/products.csv',
                      usecols=['ProductID', 'ProductName', 'SupplierID'])

# %%
suppliers.head()
# Out:
#    SupplierID                         CompanyName         City
# 0           1                      Exotic Liquids       London
# 1           2          New Orleans Cajun Delights  New Orleans
# 2           3           Grandma Kelly's Homestead    Ann Arbor
# 3           4                       Tokyo Traders        Tokyo
# 4           5  Cooperativa de Quesos 'Las Cabras'       Oviedo

# %%
products.head()
# Out:
#    ProductID                   ProductName  SupplierID
# 0          1                          Chai           1
# 1          2                         Chang           1
# 2          3                 Aniseed Syrup           1
# 3          4  Chef Anton's Cajun Seasoning           2
# 4          5        Chef Anton's Gumbo Mix           2

# %%
sup_prod = suppliers.merge(products, on='SupplierID', indicator=True)

# %%
sup_prod.head()
# Out:
#    SupplierID                 CompanyName         City  ProductID  \
# 0           1              Exotic Liquids       London          1
# 1           1              Exotic Liquids       London          2
# 2           1              Exotic Liquids       London          3
# 3           2  New Orleans Cajun Delights  New Orleans          4
# 4           2  New Orleans Cajun Delights  New Orleans          5
#
#                     ProductName _merge
# 0                          Chai   both
# 1                         Chang   both
# 2                 Aniseed Syrup   both
# 3  Chef Anton's Cajun Seasoning   both
# 4        Chef Anton's Gumbo Mix   both

# %%
suppliers.set_index('SupplierID', inplace=True)

# %%
sup_prod = suppliers.merge(right=products, on='SupplierID', indicator=True)

# %%
sup_prod.head()
# Out:
#    SupplierID                 CompanyName         City  ProductID  \
# 0           1              Exotic Liquids       London          1
# 1           1              Exotic Liquids       London          2
# 2           1              Exotic Liquids       London          3
# 3           2  New Orleans Cajun Delights  New Orleans          4
# 4           2  New Orleans Cajun Delights  New Orleans          5
#
#                     ProductName _merge
# 0                          Chai   both
# 1                         Chang   both
# 2                 Aniseed Syrup   both
# 3  Chef Anton's Cajun Seasoning   both
# 4        Chef Anton's Gumbo Mix   both

# %%
sup_prod_1 = suppliers.merge(products, left_index=True, right_on='SupplierID', indicator=True)

# %%
sup_prod_1.head()
# Out:
#                   CompanyName         City  ProductID  \
# 0              Exotic Liquids       London          1
# 1              Exotic Liquids       London          2
# 2              Exotic Liquids       London          3
# 3  New Orleans Cajun Delights  New Orleans          4
# 4  New Orleans Cajun Delights  New Orleans          5
#
#                     ProductName  SupplierID _merge
# 0                          Chai           1   both
# 1                         Chang           1   both
# 2                 Aniseed Syrup           1   both
# 3  Chef Anton's Cajun Seasoning           2   both
# 4        Chef Anton's Gumbo Mix           2   both

# %%
products.set_index('SupplierID', inplace=True)

# %%
suppliers.merge(products, indicator=True, left_index=True, right_index=True).head()
# Out:
#                            CompanyName         City  ProductID  \
# SupplierID
# 1                       Exotic Liquids       London          1
# 1                       Exotic Liquids       London          2
# 1                       Exotic Liquids       London          3
# 2           New Orleans Cajun Delights  New Orleans          4
# 2           New Orleans Cajun Delights  New Orleans          5
#
#                              ProductName _merge
# SupplierID
# 1                                   Chai   both
# 1                                  Chang   both
# 1                          Aniseed Syrup   both
# 2           Chef Anton's Cajun Seasoning   both
# 2                 Chef Anton's Gumbo Mix   both

# %%
suppliers.join(products).head()
# Out:
#                            CompanyName         City  ProductID  \
# SupplierID
# 1                       Exotic Liquids       London          1
# 1                       Exotic Liquids       London          2
# 1                       Exotic Liquids       London          3
# 2           New Orleans Cajun Delights  New Orleans          4
# 2           New Orleans Cajun Delights  New Orleans          5
#
#                              ProductName
# SupplierID
# 1                                   Chai
# 1                                  Chang
# 1                          Aniseed Syrup
# 2           Chef Anton's Cajun Seasoning
# 2                 Chef Anton's Gumbo Mix

# %%
suppliers.reset_index(inplace=True)

# %%
suppliers.merge(products, left_on='SupplierID', right_index=True, indicator=True).head()
# Out:
#    SupplierID                 CompanyName         City  ProductID  \
# 0           1              Exotic Liquids       London          1
# 0           1              Exotic Liquids       London          2
# 0           1              Exotic Liquids       London          3
# 1           2  New Orleans Cajun Delights  New Orleans          4
# 1           2  New Orleans Cajun Delights  New Orleans          5
#
#                     ProductName _merge
# 0                          Chai   both
# 0                         Chang   both
# 0                 Aniseed Syrup   both
# 1  Chef Anton's Cajun Seasoning   both
# 1        Chef Anton's Gumbo Mix   both

# %%
products.reset_index(inplace=True)

# %%
products.rename({'SupplierID':'supplier_id'}, axis='columns', inplace=True)

# %%
products.head()
# Out:
#    supplier_id  ProductID                   ProductName
# 0            1          1                          Chai
# 1            1          2                         Chang
# 2            1          3                 Aniseed Syrup
# 3            2          4  Chef Anton's Cajun Seasoning
# 4            2          5        Chef Anton's Gumbo Mix

# %%
suppliers.merge(products, left_on='SupplierID', right_on='supplier_id', indicator=True)
# Out:
#     SupplierID                 CompanyName           City  supplier_id  \
# 0            1              Exotic Liquids         London            1
# 1            1              Exotic Liquids         London            1
# 2            1              Exotic Liquids         London            1
# 3            2  New Orleans Cajun Delights    New Orleans            2
# 4            2  New Orleans Cajun Delights    New Orleans            2
# ..         ...                         ...            ...          ...
# 72          27          Escargots Nouveaux       Montceau           27
# 73          28                Gai pâturage         Annecy           28
# 74          28                Gai pâturage         Annecy           28
# 75          29            Forêts d'érables  Ste-Hyacinthe           29
# 76          29            Forêts d'érables  Ste-Hyacinthe           29
#
#     ProductID                   ProductName _merge
# 0           1                          Chai   both
# ...
